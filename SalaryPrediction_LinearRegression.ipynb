# %% [markdown]
# This dataset is imported from Salary Dataset - Simple linear regression in Kaggle
# The link is below:
# https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression

# %%
#importing dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing dataset
df = pd.read_csv('Salary_dataset.csv')
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
#visualizing the data years of experience and salary in scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['YearsExperience'], y=df['Salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
#visualizing the relationship between salary and people frequency
plt.figure(figsize=(8,6))
plt.hist(df['Salary'])
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.title("Amount of People Based on Salary")
plt.show()

# %%
#visualizing the relationship between years of experience and people frequency
plt.figure(figsize=(8,6))
plt.hist(df['YearsExperience'])
plt.xlabel("Experience")
plt.ylabel("Frequency")
plt.title("Amount of People Based on Experience Years")
plt.show()

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df['YearsExperience'], y=df['Salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df['YearsExperience']
y = df['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.5, random_state = 42)

# %%
X_train = X_train.values.reshape(-1, 1)
y_train = y_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(y_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 5.140800072406114e+17

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# -713873885.4580207

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# [27429.06584873]
# [[9162.71545776]]

# %%
lr.predict([[1.5]])
# Out:
# array([[41173.13903537]])

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
#Extracting slope & Intercept
slope = lr.coef_[0][0]
intercept = lr.intercept_[0]

X_regression = np.array([min(X), max(X)])
y_regression = slope * X_regression + intercept #ini garis regresinya (y = mx + b)
plt.scatter(X, y, color='blue', label='Data')

# Plotting regression line
plt.plot(x_regression, y_regression, color='red', label='Regression Line')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression Salary Prediction')
# Out:
# Text(0.5, 1.0, 'Linear Regression Salary Prediction')

# %%
# Creating prediction
prediction = pd.DataFrame({'New_YearsExperience': np.arange(12, 21)})

#predicting new values
predicted_y = lr.predict(prediction)
prediction['predicted_salary'] = predicted_y

prediction
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
#    New_YearsExperience  predicted_salary
# 0                   12     137381.651342
# 1                   13     146544.366800
# 2                   14     155707.082257
# 3                   15     164869.797715
# 4                   16     174032.513173
# 5                   17     183195.228631
# 6                   18     192357.944088
# 7                   19     201520.659546
# 8                   20     210683.375004
